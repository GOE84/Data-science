# %% [markdown]
# <a href="https://colab.research.google.com/github/GOE84/Data-science/blob/main/Python_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Covid-19

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/confirmed-cases-since-120864.csv')

# %%
df
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0        816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1        816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2        816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3        816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4        816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 213287  1030277     21/8/2021     20/8/2021   ชาย  47.0   ปี    Thailand
# 213288  1030278     21/8/2021     20/8/2021   ชาย  79.0   ปี    Thailand
# 213289  1030279     21/8/2021     20/8/2021   ชาย  29.0   ปี    Thailand
# 213290  1030280     21/8/2021     20/8/2021   ชาย  31.0   ปี    Thailand
# 213291  1030281     21/8/2021     20/8/2021   ชาย  46.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %%
df.head(1)
# Out:
#       No. announce_date Notified date  sex  age Unit nationality  \
# 0  816990     12/8/2021     11/8/2021  ชาย  7.0   ปี    Thailand
#
#   province_of_isolation   risk province_of_onset district_of_onset
# 0              เชียงราย  อื่นๆ               NaN               NaN

# %%
df = df[['No.','announce_date','sex','age','risk','province_of_isolation']]

# %%
df
# Out:
#             No. announce_date   sex   age  \
# 0        816990     12/8/2021   ชาย   7.0
# 1        816991     12/8/2021   ชาย   1.0
# 2        816992     12/8/2021   ชาย  35.0
# 3        816993     12/8/2021  หญิง  33.0
# 4        816994     12/8/2021  หญิง  14.0
# ...         ...           ...   ...   ...
# 213287  1030277     21/8/2021   ชาย  47.0
# 213288  1030278     21/8/2021   ชาย  79.0
# 213289  1030279     21/8/2021   ชาย  29.0
# 213290  1030280     21/8/2021   ชาย  31.0
# 213291  1030281     21/8/2021   ชาย  46.0
#
#                                                risk province_of_isolation
# 0                                             อื่นๆ              เชียงราย
# 1                                             อื่นๆ              เชียงราย
# 2                                             อื่นๆ              เชียงราย
# 3                                             อื่นๆ              เชียงราย
# 4       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้              เชียงราย
# ...

# %%
df['announce_date'].value_counts()
# Out:
# announce_date
# 13/8/2021    23418
# 12/8/2021    22782
# 14/8/2021    22086
# 15/8/2021    21882
# 16/8/2021    21157
# 19/8/2021    20902
# 21/8/2021    20571
# 18/8/2021    20515
# 17/8/2021    20128
# 20/8/2021    19851
# Name: count, dtype: int64

# %%
df['risk'].value_counts()
# Out:
# risk
# สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                                       88413
# อื่นๆ                                                                             52893
# การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน                                  29868
# อยู่ระหว่างการสอบสวน                                                              25537
# ระบุไม่ได้                                                                         5531
# สถานที่ทำงาน                                                                       3918
# ทัณฑสถาน/เรือนจำ                                                                   3164
# ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว                                      2191
# บุคลากรด้านการแพทย์และสาธารณสุข                                                     897
# อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น      373
# ตรวจก่อนทำหัตถการ                                                                   238
# ...

# %%
df['sex'].value_counts()
# Out:
# sex
# หญิง     106594
# ชาย       97452
# หญิิง         1
# Name: count, dtype: int64

# %%
df['age'].value_counts()
# Out:
# age
# 25.0     4762
# 28.0     4680
# 24.0     4644
# 30.0     4633
# 27.0     4611
#          ...
# 10.8        1
# 2.5         1
# 3.1         1
# 102.0       1
# 4.7         1
# Name: count, Length: 119, dtype: int64

# %%
df.describe()
# Out:
#                 No.            age
# count  2.132920e+05  198386.000000
# mean   9.236355e+05      36.174134
# std    6.157224e+04      17.732531
# min    8.169900e+05       1.000000
# 25%    8.703128e+05      24.000000
# 50%    9.236355e+05      35.000000
# 75%    9.769582e+05      48.000000
# max    1.030281e+06     119.000000

# %%
df['age'].hist()
# Out:
# <Axes: >

# %%
df['age'].hist(bins=[0,20,40,60,80,100,120])
# Out:
# <Axes: >

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.style.use('bmh')

fm.fontManager.addfont('thsarabunnew-webfont.ttf')

# %%
plt.style.use('bmh')
mpl.rc('font', family='TH Sarabun New')

# %%
df['age'].hist(bins=[0,20,40,60,80,100,120])
# Out:
# <Axes: >

# %%
df[(df['province_of_isolation'] == 'กรุงเทพมหานคร') & (df['announce_date'] == '12/8/2021')]
# Out:
#           No. announce_date   sex   age  \
# 17551  834541     12/8/2021  หญิง   6.0
# 17552  834542     12/8/2021   ชาย  15.0
# 17553  834543     12/8/2021  หญิง  53.0
# 17554  834544     12/8/2021   ชาย  44.0
# 17555  834545     12/8/2021   ชาย  71.0
# ...       ...           ...   ...   ...
# 22402  839392     12/8/2021  หญิง  83.0
# 22403  839393     12/8/2021   ชาย  66.0
# 22404  839394     12/8/2021  หญิง  43.0
# 22405  839395     12/8/2021  หญิง  74.0
# 22406  839396     12/8/2021   ชาย  29.0
#
#                                                     risk province_of_isolation
# 17551            ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ         กรุงเทพมหานคร
# 17552            ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ         กรุงเทพมหานคร
# 17553        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้         กรุงเทพมหานคร
# 17554        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้         กรุงเทพมหานคร
# 17555        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้         กรุงเทพมหานคร
# ...

# %%
df['province_of_isolation'].value_counts()
# Out:
# province_of_isolation
# กรุงเทพมหานคร    44484
# สมุทรสาคร        17579
# สมุทรปราการ      14051
# ชลบุรี           13639
# นนทบุรี           6727
#                  ...
# ลำพูน              163
# สตูล               159
# กระบี่             152
# พังงา              147
# แม่ฮ่องสอน          37
# Name: count, Length: 78, dtype: int64

# %%
df['announce_date'] = pd.to_datetime(df['announce_date'], format='%d/%m/%Y')
# Out:
# /tmp/ipykernel_591/4039610369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['announce_date'] = pd.to_datetime(df['announce_date'], format='%d/%m/%Y')

# %%
My_df = df[(df['province_of_isolation'] == 'ชุมพร') & (df['announce_date'] == pd.to_datetime('12/8/2021', format='%d/%m/%Y'))]

My_df
# Out:
#           No. announce_date   sex   age  \
# 15860  832850    2021-08-12  หญิง  70.0
# 15861  832851    2021-08-12   ชาย  32.0
# 15862  832852    2021-08-12   ชาย  32.0
# 15863  832853    2021-08-12   ชาย  29.0
# 15864  832854    2021-08-12   ชาย  27.0
# ...       ...           ...   ...   ...
# 15942  832932    2021-08-12   ชาย   7.0
# 15943  832933    2021-08-12  หญิง  34.0
# 15944  832934    2021-08-12  หญิง  62.0
# 15945  832935    2021-08-12   ชาย  11.0
# 15946  832936    2021-08-12  หญิง  13.0
#
#                                                    risk province_of_isolation
# 15860                                             อื่นๆ                 ชุมพร
# 15861                                             อื่นๆ                 ชุมพร
# 15862                                             อื่นๆ                 ชุมพร
# 15863                                             อื่นๆ                 ชุมพร
# 15864                                             อื่นๆ                 ชุมพร
# ...

# %%
My_df.groupby('sex').count()['No.'].plot.bar()
# Out:
# <Axes: xlabel='sex'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213292 entries, 0 to 213291
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   No.                    213292 non-null  int64
#  1   announce_date          213292 non-null  datetime64[ns]
#  2   sex                    204047 non-null  object
#  3   age                    198386 non-null  float64
#  4   risk                   213292 non-null  object
#  5   province_of_isolation  213292 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 9.8+ MB

# %%
df.head(1)
# Out:
#       No. announce_date  sex  age   risk province_of_isolation
# 0  816990    2021-08-12  ชาย  7.0  อื่นๆ              เชียงราย

# %%
df.insert(0, 'date',pd.to_datetime(df['announce_date'], format='%d/%m/%Y'),True)
df
# Out:
#              date      No. announce_date   sex   age  \
# 0      2021-08-12   816990    2021-08-12   ชาย   7.0
# 1      2021-08-12   816991    2021-08-12   ชาย   1.0
# 2      2021-08-12   816992    2021-08-12   ชาย  35.0
# 3      2021-08-12   816993    2021-08-12  หญิง  33.0
# 4      2021-08-12   816994    2021-08-12  หญิง  14.0
# ...           ...      ...           ...   ...   ...
# 213287 2021-08-21  1030277    2021-08-21   ชาย  47.0
# 213288 2021-08-21  1030278    2021-08-21   ชาย  79.0
# 213289 2021-08-21  1030279    2021-08-21   ชาย  29.0
# 213290 2021-08-21  1030280    2021-08-21   ชาย  31.0
# 213291 2021-08-21  1030281    2021-08-21   ชาย  46.0
#
#                                                risk province_of_isolation
# 0                                             อื่นๆ              เชียงราย
# 1                                             อื่นๆ              เชียงราย
# 2                                             อื่นๆ              เชียงราย
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213292 entries, 0 to 213291
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date                   213292 non-null  datetime64[ns]
#  1   No.                    213292 non-null  int64
#  2   announce_date          213292 non-null  datetime64[ns]
#  3   sex                    204047 non-null  object
#  4   age                    198386 non-null  float64
#  5   risk                   213292 non-null  object
#  6   province_of_isolation  213292 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 11.4+ MB

# %%
df.groupby('date').count()['No.'].plot.line(figsize=(12,6))
# Out:
# <Axes: xlabel='date'>
